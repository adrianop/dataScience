# %%
# %pip install optuna
import optuna
from optuna.pruners import HyperbandPruner
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Out:
# Requirement already satisfied: optuna in c:\users\adria\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\adria\anaconda3\lib\site-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in c:\users\adria\anaconda3\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\adria\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\adria\anaconda3\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\adria\anaconda3\lib\site-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in c:\users\adria\anaconda3\lib\site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in c:\users\adria\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\adria\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\adria\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\adria\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\adria\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\adria\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('df_tratado.csv', sep=',')
df.head()
# Out:
#    Unnamed: 0         id data_inversa dia_semana   horario  uf   br     km  \
# 0           2  1032898.0   2007-08-13    Segunda  14:25:00  MG   40  585.5
# 1           3  1051130.0   2007-02-12    Segunda  02:10:00  MA  135   11.0
# 2           4  1066824.0   2007-11-20      terça  05:30:00  CE  222   30.8
# 3           5  1069918.0   2007-12-16    Domingo  17:40:00  MA  230   14.0
# 4           6  1070971.0   2007-03-05    Segunda  08:10:00  PR  277  584.4
#
#          municipio               causa_acidente  ... feridos_leves  \
# 0        ITABIRITO                       Outras  ...             0
# 1         SAO LUIS             Animais na Pista  ...             2
# 2          CAUCAIA  Defeito mecânico em veículo  ...             1
# 3  BARAO DE GRAJAU                       Outras  ...             0
# 4         CASCAVEL                       Outras  ...             0
#
#   feridos_graves ilesos ignorados feridos veiculos dia mes   ano  grave
# 0              1      2         0       1        1  13   8  2007      0
# 1              1      0         0       3        1  12   2  2007      1
# 2              0      0         0       1        1  20  11  2007      0
# 3              1      0         0       1        1  16  12  2007      0
# 4              0      2         0       0        2   5   3  2007      0
#
# [5 rows x 30 columns]

# %%
features = ['dia_semana','fase_dia','condicao_metereologica','tipo_pista','veiculos']
X = df[features]
y = df['grave']

# %%
print(y.value_counts())
print(y.value_counts(normalize=True) * 100)
# Out:
# grave
# 0    1725424
# 1      74741
# Name: count, dtype: int64
# grave
# 0    95.848103
# 1     4.151897
# Name: proportion, dtype: float64

# %%
for col in X.select_dtypes(include='object').columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_10436\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\adria\AppData\Local\Temp\ipykernel_10436\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\adria\AppData\Local\Temp\ipykernel_10436\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\adria\AppData\Local\Temp\ipykernel_10436\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))

# %%
# Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'scale_pos_weight': (y_train == 0).sum() / (y_train == 1).sum(),
        'random_state': 42,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }

    model = XGBClassifier(**params)
    model.fit(X_train, y_train)

    # Previsão com threshold customizado
    y_proba = model.predict_proba(X_test)[:, 1]
    y_pred = (y_proba > 0.3).astype(int)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    # Combinação ponderada: 50% acc + 50% f1
    return (acc + f1) / 2

# %%
# ================== OTIMIZAÇÃO COM HYPERBAND ==================
pruner = HyperbandPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)
study.optimize(objective, n_trials=50, timeout=600)
# Out:
# [I 2025-07-12 17:22:48,596] A new study created in memory with name: no-name-bbabc15d-155e-486f-b554-e4f28e3df085
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:22:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:23:01,838] Trial 0 finished with value: 0.20236969078391323 and parameters: {'n_estimators': 308, 'max_depth': 9, 'learning_rate': 0.05457966433867701, 'subsample': 0.7168021133444159, 'colsample_bytree': 0.6267305834232194}. Best is trial 0 with value: 0.20236969078391323.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:23:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:23:05,980] Trial 1 finished with value: 0.09491832785919063 and parameters: {'n_estimators': 121, 'max_depth': 5, 'learning_rate': 0.013684535691036686, 'subsample': 0.9378779015007539, 'colsample_bytree': 0.7259120968085235}. Best is trial 0 with value: 0.20236969078391323.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:23:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:23:23,502] Trial 2 finished with value: 0.20087460694830736 and parameters: {'n_estimators': 324, 'max_depth': 11, 'learning_rate': 0.020992661195281995, 'subsample': 0.7717218486606404, 'colsample_bytree': 0.9687412854066114}. Best is trial 0 with value: 0.20236969078391323.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:23:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:23:37,495] Trial 3 finished with value: 0.20444177823289994 and parameters: {'n_estimators': 474, 'max_depth': 5, 'learning_rate': 0.044649581064004386, 'subsample': 0.7847859518646879, 'colsample_bytree': 0.8701749753400904}. Best is trial 3 with value: 0.20444177823289994.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:23:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:23:47,067] Trial 4 finished with value: 0.2009155713658738 and parameters: {'n_estimators': 199, 'max_depth': 9, 'learning_rate': 0.025481958955438515, 'subsample': 0.8634158775747606, 'colsample_bytree': 0.8080814187731108}. Best is trial 3 with value: 0.20444177823289994.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:23:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:24:06,817] Trial 5 finished with value: 0.20364439123130942 and parameters: {'n_estimators': 355, 'max_depth': 15, 'learning_rate': 0.026654787783322014, 'subsample': 0.8440127267851049, 'colsample_bytree': 0.9390986624782977}. Best is trial 3 with value: 0.20444177823289994.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:24:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:24:12,587] Trial 6 finished with value: 0.17674139910788939 and parameters: {'n_estimators': 246, 'max_depth': 3, 'learning_rate': 0.05858753326461061, 'subsample': 0.669628402430038, 'colsample_bytree': 0.9263301746803623}. Best is trial 3 with value: 0.20444177823289994.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:24:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:24:52,723] Trial 7 finished with value: 0.20532472659041806 and parameters: {'n_estimators': 721, 'max_depth': 13, 'learning_rate': 0.025348747246129413, 'subsample': 0.6178840632877073, 'colsample_bytree': 0.8697598105900147}. Best is trial 7 with value: 0.20532472659041806.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:24:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:25:29,086] Trial 8 finished with value: 0.20325540446024826 and parameters: {'n_estimators': 717, 'max_depth': 11, 'learning_rate': 0.013948826519202684, 'subsample': 0.9783908964830232, 'colsample_bytree': 0.9459302623840947}. Best is trial 7 with value: 0.20532472659041806.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:25:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:25:54,873] Trial 9 finished with value: 0.20214928057889409 and parameters: {'n_estimators': 605, 'max_depth': 13, 'learning_rate': 0.046363003288514865, 'subsample': 0.7997275350606601, 'colsample_bytree': 0.7435336070276575}. Best is trial 7 with value: 0.20532472659041806.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:25:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:26:50,541] Trial 10 finished with value: 0.20635839030357297 and parameters: {'n_estimators': 977, 'max_depth': 14, 'learning_rate': 0.18421688954874094, 'subsample': 0.601440144721393, 'colsample_bytree': 0.8547460474881254}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:26:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:27:47,433] Trial 11 finished with value: 0.20503821431384386 and parameters: {'n_estimators': 984, 'max_depth': 15, 'learning_rate': 0.24455645098948178, 'subsample': 0.6123938997519516, 'colsample_bytree': 0.8469395021298929}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:27:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:28:40,293] Trial 12 finished with value: 0.20603018565470319 and parameters: {'n_estimators': 965, 'max_depth': 12, 'learning_rate': 0.20773259461857024, 'subsample': 0.6026681819329194, 'colsample_bytree': 0.8710775952705365}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:28:40] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:29:22,200] Trial 13 finished with value: 0.20352498515125264 and parameters: {'n_estimators': 977, 'max_depth': 12, 'learning_rate': 0.24932865077445315, 'subsample': 0.6936262830590899, 'colsample_bytree': 0.7643241539665984}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:29:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:29:59,512] Trial 14 finished with value: 0.20177065231006563 and parameters: {'n_estimators': 855, 'max_depth': 14, 'learning_rate': 0.11433376321260744, 'subsample': 0.601855547924753, 'colsample_bytree': 0.6804311164262412}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:29:59] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:30:41,803] Trial 15 finished with value: 0.2054160549940252 and parameters: {'n_estimators': 845, 'max_depth': 10, 'learning_rate': 0.139782080334186, 'subsample': 0.6769012693458355, 'colsample_bytree': 0.9981139774762008}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:30:41] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:31:18,151] Trial 16 finished with value: 0.20463055243280964 and parameters: {'n_estimators': 854, 'max_depth': 8, 'learning_rate': 0.13998481334552368, 'subsample': 0.7407140643382134, 'colsample_bytree': 0.8196564978762283}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:31:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:32:00,727] Trial 17 finished with value: 0.2054230572684409 and parameters: {'n_estimators': 706, 'max_depth': 13, 'learning_rate': 0.08969837555646039, 'subsample': 0.6529881944243922, 'colsample_bytree': 0.8907288967462694}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:32:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:32:35,211] Trial 18 finished with value: 0.20350698124473815 and parameters: {'n_estimators': 910, 'max_depth': 7, 'learning_rate': 0.27774916438123376, 'subsample': 0.641938088330893, 'colsample_bytree': 0.7756465779761627}. Best is trial 10 with value: 0.20635839030357297.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:32:35] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-12 17:33:05,233] Trial 19 finished with value: 0.20517276992682587 and parameters: {'n_estimators': 533, 'max_depth': 12, 'learning_rate': 0.18265046286233885, 'subsample': 0.7381353185536066, 'colsample_bytree': 0.9036218360903688}. Best is trial 10 with value: 0.20635839030357297.

# %%
# ================== MELHOR MODELO ==================
print("Melhores hiperparâmetros encontrados:")
print(study.best_params)

# Avaliação final com melhor modelo
best_model = XGBClassifier(**study.best_params)
best_model.fit(X_train, y_train)
y_proba = best_model.predict_proba(X_test)[:, 1]
y_pred = (y_proba > 0.3).astype(int)

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, zero_division=0)

print(f"\n✅ Resultado final com melhores parâmetros:")
print(f"Acurácia:  {acc:.4f}")
print(f"F1-Score:  {f1:.4f}")
# Out:
# Melhores hiperparâmetros encontrados:
# {'n_estimators': 977, 'max_depth': 14, 'learning_rate': 0.18421688954874094, 'subsample': 0.601440144721393, 'colsample_bytree': 0.8547460474881254}
#
# ✅ Resultado final com melhores parâmetros:
# Acurácia:  0.9581
# F1-Score:  0.0047
