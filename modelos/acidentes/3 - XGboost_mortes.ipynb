# %%
# %pip install optuna
import optuna
from optuna.pruners import HyperbandPruner
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Out:
# Requirement already satisfied: optuna in c:\users\adria\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\adria\anaconda3\lib\site-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in c:\users\adria\anaconda3\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\adria\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\adria\anaconda3\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\adria\anaconda3\lib\site-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in c:\users\adria\anaconda3\lib\site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in c:\users\adria\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\adria\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\adria\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\adria\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\adria\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\adria\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('df_tratado.csv', sep=',')
df.head()
# Out:
#    Unnamed: 0        id data_inversa dia_semana   horario  uf   br     km  \
# 0           1  405158.0   2022-01-01     Sábado  02:40:00  PR  116   33.0
# 1          28  405442.0   2022-02-01    Domingo  12:00:00  SC  116   54.0
# 2          34  405542.0   2022-02-01    Domingo  18:40:00  RS  290  112.0
# 3          36  405558.0   2022-02-01    Domingo  23:00:00  SC  101  118.0
# 4          38  405589.0   2022-03-01    Segunda  03:30:00  SC  101  329.0
#
#                municipio                                     causa_acidente  \
# 0  CAMPINA GRANDE DO SUL                   Ingestão de álcool pelo condutor
# 1              PAPANDUVA                            Velocidade Incompatível
# 2        ELDORADO DO SUL  Acessar a via sem observar a presença dos outr...
# 3                 ITAJAI                   Ingestão de álcool pelo condutor
# 4      CAPIVARI DE BAIXO                   Ingestão de álcool pelo condutor
#
#    ...      latitude     longitude regional delegacia             uop  \
# 0  ...    -25,114403   -48,8467554  SPRF-PR  DEL01-PR  UOP02-DEL01-PR
# 1  ...  -26,39448417  -50,16480003  SPRF-SC  DEL06-SC  UOP02-DEL06-SC
# 2  ...    -30,040455    -51,329193  SPRF-RS  DEL02-RS  UOP01-DEL02-RS
# 3  ...    -26,895859     -48,71903  SPRF-SC  DEL04-SC  UOP04-DEL04-SC
# 4  ...  -28,45039264  -48,97180974  SPRF-SC  DEL02-SC  UOP01-DEL02-SC
#
#      origem_arquivo dia mes   ano  grave
# 0  datatran2022.csv   1   1  2022      1
# 1  datatran2022.csv   1   2  2022      0
# 2  datatran2022.csv   1   2  2022      0
# 3  datatran2022.csv   1   2  2022      0
# 4  datatran2022.csv   1   3  2022      0
#
# [5 rows x 36 columns]

# %%
features = ['dia_semana','fase_dia','condicao_metereologica','tipo_pista','veiculos']
X = df[features]
y = df['grave']

# %%
print(y.value_counts())
print(y.value_counts(normalize=True) * 100)
# Out:
# grave
# 0    35517
# 1     1121
# Name: count, dtype: int64
# grave
# 0    96.940335
# 1     3.059665
# Name: proportion, dtype: float64

# %%
for col in X.select_dtypes(include='object').columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_19356\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\adria\AppData\Local\Temp\ipykernel_19356\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\adria\AppData\Local\Temp\ipykernel_19356\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\adria\AppData\Local\Temp\ipykernel_19356\1733159600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))

# %%
# Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'scale_pos_weight': (y_train == 0).sum() / (y_train == 1).sum(),
        'random_state': 42,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }

    model = XGBClassifier(**params)
    model.fit(X_train, y_train)

    # Previsão com threshold customizado
    y_proba = model.predict_proba(X_test)[:, 1]
    y_pred = (y_proba > 0.3).astype(int)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    # Combinação ponderada: 50% acc + 50% f1
    return (acc + f1) / 2

# %%
# ================== OTIMIZAÇÃO COM HYPERBAND ==================
pruner = HyperbandPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)
study.optimize(objective, n_trials=50, timeout=600)
# Out:
# [I 2025-08-03 15:56:33,186] A new study created in memory with name: no-name-c02b4b20-ec21-4ac9-ac82-eb37cec4b6df
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:33] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:33,885] Trial 0 finished with value: 0.23816372582789797 and parameters: {'n_estimators': 293, 'max_depth': 4, 'learning_rate': 0.24670291156681673, 'subsample': 0.7249191174783913, 'colsample_bytree': 0.9076836850775086}. Best is trial 0 with value: 0.23816372582789797.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:33] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:34,681] Trial 1 finished with value: 0.23618973762291443 and parameters: {'n_estimators': 479, 'max_depth': 8, 'learning_rate': 0.012561894690007125, 'subsample': 0.6245242350220694, 'colsample_bytree': 0.9026620124596854}. Best is trial 0 with value: 0.23816372582789797.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:34] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:35,713] Trial 2 finished with value: 0.2609817860341056 and parameters: {'n_estimators': 523, 'max_depth': 12, 'learning_rate': 0.1790638622711798, 'subsample': 0.7415188708460063, 'colsample_bytree': 0.8567126295703773}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:35] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:36,707] Trial 3 finished with value: 0.23837074090455102 and parameters: {'n_estimators': 473, 'max_depth': 15, 'learning_rate': 0.01598327776309463, 'subsample': 0.6243408360243127, 'colsample_bytree': 0.8375123002433514}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:36] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:37,383] Trial 4 finished with value: 0.21823968511060782 and parameters: {'n_estimators': 402, 'max_depth': 14, 'learning_rate': 0.038932349473957774, 'subsample': 0.7467707775575161, 'colsample_bytree': 0.6981571628273316}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:37,641] Trial 5 finished with value: 0.24597294530771419 and parameters: {'n_estimators': 102, 'max_depth': 12, 'learning_rate': 0.07413356508753101, 'subsample': 0.7045506748766313, 'colsample_bytree': 0.9517781091318862}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:37,920] Trial 6 finished with value: 0.2197964911119933 and parameters: {'n_estimators': 182, 'max_depth': 15, 'learning_rate': 0.15103479184963903, 'subsample': 0.8209621580871349, 'colsample_bytree': 0.720281221088518}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:38,976] Trial 7 finished with value: 0.23029216828657406 and parameters: {'n_estimators': 630, 'max_depth': 8, 'learning_rate': 0.012698227098026827, 'subsample': 0.7665192962907359, 'colsample_bytree': 0.9139363517906866}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:39,248] Trial 8 finished with value: 0.21266236220867038 and parameters: {'n_estimators': 128, 'max_depth': 14, 'learning_rate': 0.03231604099641517, 'subsample': 0.8153234276157819, 'colsample_bytree': 0.8201939126822522}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:39,501] Trial 9 finished with value: 0.23477868608808075 and parameters: {'n_estimators': 255, 'max_depth': 5, 'learning_rate': 0.05968103740904142, 'subsample': 0.6995696350592562, 'colsample_bytree': 0.8898865094250745}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:40,741] Trial 10 finished with value: 0.2336627487407837 and parameters: {'n_estimators': 873, 'max_depth': 11, 'learning_rate': 0.29900154986548094, 'subsample': 0.9508884986207203, 'colsample_bytree': 0.6091133883600502}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:40] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:42,338] Trial 11 finished with value: 0.2525127222369975 and parameters: {'n_estimators': 753, 'max_depth': 11, 'learning_rate': 0.0996845998317048, 'subsample': 0.865076231162563, 'colsample_bytree': 0.9820779163772271}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:43,660] Trial 12 finished with value: 0.24734137695732672 and parameters: {'n_estimators': 701, 'max_depth': 11, 'learning_rate': 0.13166159708223768, 'subsample': 0.8926418345289953, 'colsample_bytree': 0.9804783915304963}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:44,920] Trial 13 finished with value: 0.22089647397898293 and parameters: {'n_estimators': 874, 'max_depth': 10, 'learning_rate': 0.11305866383179547, 'subsample': 0.8739623941214222, 'colsample_bytree': 0.7606195016875787}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:44] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:46,237] Trial 14 finished with value: 0.24536325063920425 and parameters: {'n_estimators': 689, 'max_depth': 12, 'learning_rate': 0.1807598139433601, 'subsample': 0.9821509705820037, 'colsample_bytree': 0.843523868503556}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:46] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:47,467] Trial 15 finished with value: 0.24062891589139926 and parameters: {'n_estimators': 974, 'max_depth': 6, 'learning_rate': 0.08920293707084531, 'subsample': 0.8673532386153493, 'colsample_bytree': 0.9857074057196104}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:48,553] Trial 16 finished with value: 0.21087625351675096 and parameters: {'n_estimators': 765, 'max_depth': 9, 'learning_rate': 0.20429095858292684, 'subsample': 0.9071319058815492, 'colsample_bytree': 0.7936967828062742}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:49,721] Trial 17 finished with value: 0.2449559037588835 and parameters: {'n_estimators': 609, 'max_depth': 13, 'learning_rate': 0.0433263052041504, 'subsample': 0.7884755652955417, 'colsample_bytree': 0.8687939369492435}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:50,453] Trial 18 finished with value: 0.24128622241529032 and parameters: {'n_estimators': 535, 'max_depth': 7, 'learning_rate': 0.09292906920211312, 'subsample': 0.6665552675864289, 'colsample_bytree': 0.9443129964784888}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:51,898] Trial 19 finished with value: 0.24558843836317773 and parameters: {'n_estimators': 811, 'max_depth': 10, 'learning_rate': 0.0644351866520083, 'subsample': 0.9334107665933075, 'colsample_bytree': 0.998883116420414}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:53,360] Trial 20 finished with value: 0.211652998766013 and parameters: {'n_estimators': 991, 'max_depth': 13, 'learning_rate': 0.02552017232532683, 'subsample': 0.8420210243824651, 'colsample_bytree': 0.6443584236556515}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:54,774] Trial 21 finished with value: 0.25096342002720684 and parameters: {'n_estimators': 678, 'max_depth': 11, 'learning_rate': 0.1323927593264562, 'subsample': 0.8812919080048409, 'colsample_bytree': 0.9558956125915408}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:56,216] Trial 22 finished with value: 0.25498086405481735 and parameters: {'n_estimators': 603, 'max_depth': 11, 'learning_rate': 0.11983820756903237, 'subsample': 0.7860547376335288, 'colsample_bytree': 0.9560688886693066}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:57,189] Trial 23 finished with value: 0.24523562523933798 and parameters: {'n_estimators': 567, 'max_depth': 9, 'learning_rate': 0.09587909839454833, 'subsample': 0.7923920902517686, 'colsample_bytree': 0.9328414198315607}. Best is trial 2 with value: 0.2609817860341056.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:57] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:57,886] Trial 24 finished with value: 0.262584435963665 and parameters: {'n_estimators': 366, 'max_depth': 12, 'learning_rate': 0.1888534132836027, 'subsample': 0.7441905120685195, 'colsample_bytree': 0.873900272648435}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:57] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:58,635] Trial 25 finished with value: 0.2511092404552709 and parameters: {'n_estimators': 369, 'max_depth': 13, 'learning_rate': 0.18858524588092748, 'subsample': 0.748637782605698, 'colsample_bytree': 0.8681489539601979}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:58] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:56:59,176] Trial 26 finished with value: 0.23839550303671986 and parameters: {'n_estimators': 363, 'max_depth': 12, 'learning_rate': 0.2513705336010809, 'subsample': 0.6515378637451799, 'colsample_bytree': 0.7768058098273831}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:56:59] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:00,127] Trial 27 finished with value: 0.24047433354188047 and parameters: {'n_estimators': 462, 'max_depth': 10, 'learning_rate': 0.1880223905844756, 'subsample': 0.6835731362817002, 'colsample_bytree': 0.8691808060265714}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:00,746] Trial 28 finished with value: 0.23926772960717219 and parameters: {'n_estimators': 307, 'max_depth': 14, 'learning_rate': 0.1524930785584759, 'subsample': 0.7252684986456601, 'colsample_bytree': 0.8209037918078135}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:01,732] Trial 29 finished with value: 0.25409986293947023 and parameters: {'n_estimators': 527, 'max_depth': 12, 'learning_rate': 0.2598030438775507, 'subsample': 0.7707288284101813, 'colsample_bytree': 0.920773184537245}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:01,965] Trial 30 finished with value: 0.22275602545541576 and parameters: {'n_estimators': 232, 'max_depth': 4, 'learning_rate': 0.23597109850741957, 'subsample': 0.7333934763027035, 'colsample_bytree': 0.8889859665500264}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:03,065] Trial 31 finished with value: 0.2545231265256875 and parameters: {'n_estimators': 554, 'max_depth': 12, 'learning_rate': 0.2931881550039301, 'subsample': 0.7672021110784952, 'colsample_bytree': 0.9167554368984293}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:03,862] Trial 32 finished with value: 0.24748555713420112 and parameters: {'n_estimators': 425, 'max_depth': 13, 'learning_rate': 0.2977303103084335, 'subsample': 0.769111989694515, 'colsample_bytree': 0.8874781401523976}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:04,922] Trial 33 finished with value: 0.24609427150024704 and parameters: {'n_estimators': 588, 'max_depth': 10, 'learning_rate': 0.22095086232519406, 'subsample': 0.8249736098970181, 'colsample_bytree': 0.8472409237388813}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:05,890] Trial 34 finished with value: 0.2508000912207652 and parameters: {'n_estimators': 501, 'max_depth': 12, 'learning_rate': 0.1533215665616, 'subsample': 0.711214416271011, 'colsample_bytree': 0.9223171595533711}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:05] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:06,788] Trial 35 finished with value: 0.2581404380851048 and parameters: {'n_estimators': 440, 'max_depth': 14, 'learning_rate': 0.12501887576776008, 'subsample': 0.7426557779749494, 'colsample_bytree': 0.9622834952192267}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:07,548] Trial 36 finished with value: 0.24266323442684823 and parameters: {'n_estimators': 319, 'max_depth': 15, 'learning_rate': 0.07965540070964028, 'subsample': 0.6434147447818043, 'colsample_bytree': 0.9497852577254909}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:07] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:08,459] Trial 37 finished with value: 0.24547710725904545 and parameters: {'n_estimators': 458, 'max_depth': 15, 'learning_rate': 0.12559973943193747, 'subsample': 0.746273058129802, 'colsample_bytree': 0.9640893577581277}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:09,074] Trial 38 finished with value: 0.22988303051678188 and parameters: {'n_estimators': 407, 'max_depth': 14, 'learning_rate': 0.11343416365420539, 'subsample': 0.6801712987163449, 'colsample_bytree': 0.742655803977647}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:10,102] Trial 39 finished with value: 0.24474540863029584 and parameters: {'n_estimators': 636, 'max_depth': 8, 'learning_rate': 0.1619677324414825, 'subsample': 0.8050601223051764, 'colsample_bytree': 0.8199397828658826}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:10,843] Trial 40 finished with value: 0.24670779769468434 and parameters: {'n_estimators': 358, 'max_depth': 14, 'learning_rate': 0.06986081003939175, 'subsample': 0.839034907754373, 'colsample_bytree': 0.903842726003589}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:11,803] Trial 41 finished with value: 0.24808465899590537 and parameters: {'n_estimators': 501, 'max_depth': 13, 'learning_rate': 0.05065288603832607, 'subsample': 0.758837213267096, 'colsample_bytree': 0.9350007969162533}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:12,824] Trial 42 finished with value: 0.24813583334091688 and parameters: {'n_estimators': 430, 'max_depth': 12, 'learning_rate': 0.1709431034761442, 'subsample': 0.6070976174905913, 'colsample_bytree': 0.9705733861572391}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:13,928] Trial 43 finished with value: 0.23585330879386282 and parameters: {'n_estimators': 566, 'max_depth': 11, 'learning_rate': 0.20598054432181434, 'subsample': 0.7874777468908375, 'colsample_bytree': 0.9117144544161578}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:15,210] Trial 44 finished with value: 0.25485831571233747 and parameters: {'n_estimators': 641, 'max_depth': 14, 'learning_rate': 0.2596383057955548, 'subsample': 0.7042145236107191, 'colsample_bytree': 0.8573092171019544}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:16,515] Trial 45 finished with value: 0.24384304558875522 and parameters: {'n_estimators': 633, 'max_depth': 15, 'learning_rate': 0.01922383858487638, 'subsample': 0.700482552735878, 'colsample_bytree': 0.8503579725822551}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:17,527] Trial 46 finished with value: 0.21264579991115018 and parameters: {'n_estimators': 656, 'max_depth': 14, 'learning_rate': 0.13673287200703008, 'subsample': 0.7151215304995859, 'colsample_bytree': 0.7980014887213224}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:18,943] Trial 47 finished with value: 0.25231059421887087 and parameters: {'n_estimators': 733, 'max_depth': 14, 'learning_rate': 0.2334011759258648, 'subsample': 0.7424280481116232, 'colsample_bytree': 0.8309314468624347}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:19,427] Trial 48 finished with value: 0.2598222377587256 and parameters: {'n_estimators': 237, 'max_depth': 13, 'learning_rate': 0.12058179212773901, 'subsample': 0.7234123003893871, 'colsample_bytree': 0.8767918677011806}. Best is trial 24 with value: 0.262584435963665.
# c:\Users\adria\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:57:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-03 15:57:19,907] Trial 49 finished with value: 0.2574127264970135 and parameters: {'n_estimators': 239, 'max_depth': 11, 'learning_rate': 0.11181089255317916, 'subsample': 0.7292809340317029, 'colsample_bytree': 0.8951593871378751}. Best is trial 24 with value: 0.262584435963665.

# %%
# ================== MELHOR MODELO ==================
print("Melhores hiperparâmetros encontrados:")
print(study.best_params)

# Avaliação final com melhor modelo
best_model = XGBClassifier(**study.best_params)
best_model.fit(X_train, y_train)
y_proba = best_model.predict_proba(X_test)[:, 1]
y_pred = (y_proba > 0.3).astype(int)

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, zero_division=0)

print(f"\n✅ Resultado final com melhores parâmetros:")
print(f"Acurácia:  {acc:.4f}")
print(f"F1-Score:  {f1:.4f}")
# Out:
# Melhores hiperparâmetros encontrados:
# {'n_estimators': 366, 'max_depth': 12, 'learning_rate': 0.1888534132836027, 'subsample': 0.7441905120685195, 'colsample_bytree': 0.873900272648435}
#
# ✅ Resultado final com melhores parâmetros:
# Acurácia:  0.9664
# F1-Score:  0.0160
